# %% [markdown]
# <a href="https://colab.research.google.com/github/Thun-tula/BSC_DPDM2025/blob/main/Ch3_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import data**

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
flood = pd.read_csv('/content/drive/MyDrive/BSC_DPDM_2025/data/flooding database.csv')
flood.head()
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# ...

# %% [markdown]
# #**Data Cleaning**

# %% [markdown]
# ##**Missing Data**

# %% [markdown]
# ### **Check Missing Data**

# %%
flood.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ###Drob Record ที่มี missing ออก

# %%
flood.shape
# Out:
# (913, 23)

# %%
flood_drob = flood.dropna()
flood_drob.shape
# Out:
# (13, 23)

# %% [markdown]
#  Drob เฉพาะเกิด missing ในตัวแปรที่เราจะใช้
#
# -dfo_country
#
# -dfo_other_country
#
# -dfo_began
#
# -dfo_ended
#
# -dfo_dead
#
# -dfo_cause
#
# -dfo_severity

# %%
flood_drob2 = flood.dropna(subset=['dfo_country','dfo_other_country','dfo_began','dfo_ended','dfo_dead','dfo_cause','dfo_severity'])
flood_drob2.shape
# Out:
# (637, 23)

# %%
flood_drob2.head()
# Out:
#                          system:index  index threshold_type glide_index  \
# 0  DFO_1586_From_20000218_to_20000301   1586           otsu           0
# 1  DFO_1587_From_20000217_to_20000311   1587           otsu           0
# 2  DFO_1595_From_20000405_to_20000425   1595           otsu           0
# 3  DFO_1614_From_20000711_to_20000810   1614           otsu           0
# 4  DFO_1627_From_20000830_to_20000910   1627           otsu           0
#
#   dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 0   Australia                 0      143.697800      -31.268059   2/18/00
# 1  Madagascar                 0       47.295670      -15.782624   2/17/00
# 2     Romania           Hungary       22.415404       46.763746    4/5/00
# 3    Thailand           Vietnam      105.063841       11.242567   7/11/00
# 4       China            Russia      132.057679       43.773883   8/30/00
#
#   dfo_ended  ...              dfo_cause  dfo_severity  gfd_area  \
# ...

# %% [markdown]
# ## เติม Dummy

# %%
flood[flood.isnull()['dfo_other_country']]
# Out:
#                            system:index  index threshold_type  \
# 172  DFO_2415_From_20040110_to_20040119   2415            std
# 383  DFO_3089_From_20070530_to_20070603   3089            std
# 387  DFO_3097_From_20070611_to_20070624   3097            std
# 412  DFO_3136_From_20070721_to_20071015   3136            std
# 428  DFO_3166_From_20070726_to_20071010   3166            std
# ..                                  ...    ...            ...
# 908  DFO_4683_From_20180901_to_20181002   4683            std
# 909  DFO_4695_From_20181023_to_20181027   4695            std
# 910  DFO_4703_From_20181029_to_20181107   4703           otsu
# 911  DFO_4704_From_20181124_to_20181129   4704            std
# 912  DFO_4711_From_20181205_to_20181210   4711            std
#
#             glide_index         dfo_country dfo_other_country  dfo_centroid_x  \
# 172                   0                Iran               NaN       51.439491
# ...

# %%
flood_filldummy = flood.fillna(value={'dfo_other_country':'Unknown'})
flood_filldummy.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country      0
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              2
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติม missing ด้วยค่ากลาง

# %%
flood.groupby("dfo_cause").count()
# Out:
#                        system:index  index  threshold_type  glide_index  \
# dfo_cause
# Dam                              13     13              13           11
# Heavy rain                      749    749             749          554
# Snowmelt, Ice, Rain              52     52              52           45
# Tropical Storm, Surge            97     97              97           71
#
#                        dfo_country  dfo_other_country  dfo_centroid_x  \
# dfo_cause
# Dam                             13                 10              13
# Heavy rain                     749                530             749
# Snowmelt, Ice, Rain             52                 45              52
# Tropical Storm, Surge           97                 53              97
#
#                        dfo_centroid_y  dfo_began  dfo_ended  ...  \
# dfo_cause                                                    ...
# Dam                                13         13         13  ...
# ...

# %%
flood_fillmode = flood.fillna(value={'dfo_cause':'Heavy rain'})
flood_fillmode.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ### เติม missing ด้วยตัวแทนของกลุ่ม

# %%
flood.groupby(["dfo_severity","dfo_cause"]).count()
# Out:
#                                     system:index  index  threshold_type  \
# dfo_severity dfo_cause
# 1.0          Dam                               9      9               9
#              Heavy rain                      464    464             464
#              Snowmelt, Ice, Rain              34     34              34
#              Tropical Storm, Surge            33     33              33
# 1.5          Dam                               3      3               3
#              Heavy rain                      163    163             163
#              Snowmelt, Ice, Rain               8      8               8
#              Tropical Storm, Surge            26     26              26
# 2.0          Dam                               1      1               1
#              Heavy rain                      122    122             122
#              Snowmelt, Ice, Rain              10     10              10
#              Tropical Storm, Surge            38     38              38
#
# ...

# %%
flood_sever1 = flood[flood['dfo_severity'] == 1.0]
flood_sever15 = flood[flood['dfo_severity'] == 1.5]
flood_sever2 = flood[flood['dfo_severity'] == 2.0]

# %%
sever1 = flood_sever1.fillna(value={'dfo_cause':'Heavy rain'})
sever15 = flood_sever15.fillna(value={'dfo_cause':'Heavy rain'})
sever2 = flood_sever2.fillna(value={'dfo_cause':'Tropical Storm, Surge'})

# %%
flood_fillgroup = pd.concat([sever1,sever15,sever2])

# %%
flood_fillgroup.isnull().sum()
# Out:
# system:index           0
# index                  0
# threshold_type         0
# glide_index          232
# dfo_country            0
# dfo_other_country    275
# dfo_centroid_x         0
# dfo_centroid_y         0
# dfo_began              0
# dfo_ended              1
# dfo_validation         2
# dfo_dead               0
# dfo_displaced          0
# dfo_cause              0
# dfo_severity           0
# gfd_area               0
# gfd_exp_ghsl_ts        1
# gfd_exp_ghsl_2000      1
# gfd_exp_ghsl_2015      0
# Errors                 0
# dif 2000               0
# dif 2015               0
# error 2000           889
# dtype: int64

# %% [markdown]
# ##Noisy Data

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(flood['gfd_area'])

# %% [markdown]
# ใช้ histogram ดู Bin ที่เหมาะสม

# %%
outputhist = plt.hist(flood['gfd_area'],bins=30)

# %%
import numpy as np

def calculate_bin_midpoints(bin_edges):
    """
    Calculates the midpoints of histogram bins.

    Args:
        bin_edges (array-like): An array containing the edges of the histogram bins.

    Returns:
        list: A list of midpoints for each bin.
    """
    midpoints = []
    for i in range(len(bin_edges) - 1):
        mid = (bin_edges[i] + bin_edges[i+1]) / 2
        midpoints.append(mid)
    return midpoints

# Assuming outputhist is available from the previous cell
# outputhist[1] contains the bin edges
bin_midpoints = calculate_bin_midpoints(outputhist[1])

print("Average (midpoint) of each bin:")
for i, midpoint in enumerate(bin_midpoints):
    print(f"Bin {i+1}: {midpoint:.2f}")
# Out:
# Average (midpoint) of each bin:
# Bin 1: 1642.46
# Bin 2: 4927.38
# Bin 3: 8212.30
# Bin 4: 11497.22
# Bin 5: 14782.14
# Bin 6: 18067.06
# Bin 7: 21351.98
# Bin 8: 24636.90
# Bin 9: 27921.83
# Bin 10: 31206.75
# Bin 11: 34491.67
# Bin 12: 37776.59
# Bin 13: 41061.51
# Bin 14: 44346.43
# Bin 15: 47631.35
# Bin 16: 50916.27
# Bin 17: 54201.19
# Bin 18: 57486.11
# Bin 19: 60771.03
# Bin 20: 64055.95
# Bin 21: 67340.87
# Bin 22: 70625.79
# Bin 23: 73910.71
# Bin 24: 77195.64
# Bin 25: 80480.56
# Bin 26: 83765.48
# Bin 27: 87050.40
# Bin 28: 90335.32
# Bin 29: 93620.24
# Bin 30: 96905.16

# %%
def put_vlue_into_bins(value,bin_edges):
    for i in range(len(bin_edges) - 1):
        if value >= bin_edges[i] and value < bin_edges[i+1]:
            new_val = (bin_edges[i] + bin_edges[i+1] - bin_edges[i])/2
            return new_val

# %%
put_vlue_into_bins(3000,outputhist[1])
# Out:
# np.float64(1642.4603333333332)

# %%
flood['gfd_area_bin'] = flood['gfd_area'].apply( lambda x: put_vlue_into_bins(x,outputhist[1]))

# %%
plt.plot(flood['gfd_area_bin'])

# %%
plt.subplot(2,1,1)
plt.plot(flood['gfd_area'])
plt.subplot(2,1,2)
plt.plot(flood['gfd_area_bin'])

# %%
plt.subplot(2,1,1)
plt.plot(flood['gfd_area'].sort_values().reset_index(drop=True))
plt.subplot(2,1,2)
plt.plot(flood['gfd_area_bin'].sort_values().reset_index(drop=True))

# %% [markdown]
# ###Outlier Removal

# %%
outputbox = plt.boxplot(flood['gfd_area'],vert=False,whis=10);

# %% [markdown]
# remove outlier

# %%
flood_nooutlier = flood[flood['gfd_area'] < outputbox['whiskers'][1].get_xdata()[1]]

# %%
outputbox2 = plt.boxplot(flood_nooutlier['gfd_area'],vert=False,whis=10);

# %% [markdown]
# ตามหาค่า outlier

# %%
flood[flood['gfd_area']== outputbox['whiskers'][0].get_xdata()[0]]
# Out:
#                            system:index  index threshold_type glide_index  \
# 872  DFO_4485_From_20170612_to_20170614   4485            std         NaN
#
#      dfo_country dfo_other_country  dfo_centroid_x  dfo_centroid_y dfo_began  \
# 872  Philippines               NaN      125.249498         7.76344   6/12/17
#
#     dfo_ended  ... dfo_severity  gfd_area  gfd_exp_ghsl_ts gfd_exp_ghsl_2000  \
# 872   6/14/17  ...          1.0     608.6         359310.0          308601.0
#
#      gfd_exp_ghsl_2015  Errors  dif 2000  dif 2015  error 2000  gfd_area_bin
# 872             359310       1     50709         0         NaN   1642.460333
#
# [1 rows x 24 columns]
